# %% [markdown]
# # Generation of candidate suspect list
#
# Julia M. Gauglitz
#
# Date: 4/20/2020

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read in GNPS files

# %%
IDs = pd.read_csv("MSV000078547_identifications.tsv", sep='\t')
pairs = pd.read_csv("MSV000078547_pairs.tsv", sep='\t')
summary = pd.read_csv("MSV000078547_summary.tsv", sep='\t')

# %% [markdown]
# Define library ID inclusion criteria:
# 1. MZErrorPPM <= 20
# 2. SharedPeaks >= 6
# 3. Include only entries with an INCHI; INCHI is not equal to 'N/A'

# %%
INCHI = IDs['INCHI']
INCHI_TF = INCHI.notna()

# %%
#adding column with TF values for INCHI
IDs['INCHI_TF'] = INCHI_TF

# %%
#subset table to only include rows that have low ppm error and 6 or more shared peaks
IDs_subset = IDs.loc[(IDs['MZErrorPPM'] <= 20.0) & (IDs['SharedPeaks'] >= 6) & (IDs['INCHI_TF'] == True)]

# %%
IDs_subset.head()
# Out:
#                       Compound_Name Ion_Source   Instrument Compound_Source  \
# 10                  C17-Sphinganine     LC-ESI         qTof          Lysate
# 11                      Beauvericin        ESI          HCD        Isolated
# 30  Ethylenediaminetetraacetic acid        ESI  IT/ion trap        Isolated
# 41  Ethylenediaminetetraacetic acid        ESI  IT/ion trap        Isolated
# 42                        Erucamide        ESI  IT/ion trap        Isolated
#
#             PI Data_Collector   Adduct  Scan  Precursor_MZ  ExactMass  ...  \
# 10  Dorrestein          Quinn      M+H    -1       288.291    287.481  ...
# 11        NIST           NIST     M+Na    -1       806.399      0.000  ...
# 30        NIST           NIST     M+Na    -1       315.080      0.000  ...
# 41        NIST           NIST  M-H+2Na    -1       337.062      0.000  ...
# 42        NIST           NIST      M+H    -1       338.342      0.000  ...
#
#                 Organism TIC_Query RT_Query MZErrorPPM SharedPeaks  MassDiff  \
# 10          GNPS-LIBRARY   7763.21        0    3.38742           7  0.000977
# 11  nist_17_gnps_library   3850.47        0    1.66515           7  0.001343
# 30  nist_17_gnps_library   1832.68        0    0.29057           7  0.000092
# 41  nist_17_gnps_library   1944.67        0    5.34186           8  0.001801
# 42  nist_17_gnps_library  21550.60        0    4.23928           7  0.001434
#
#       LibMZ   SpecMZ SpecCharge INCHI_TF
# 10  288.291  288.290          0     True
# 11  806.399  806.400          0     True
# 30  315.080  315.080          0     True
# 41  337.062  337.060          0     True
# 42  338.342  338.343          1     True
#
# [5 rows x 36 columns]

# %% [markdown]
# Define criteria for pairs dictionary to include as candidate analog annotations (didn't filter any in example MSV000078547)
# 1. Cosine >= 0.8
# 2. Define DeltaMZ to be taken into account (i.e. 14, 16, 28); m/z delta +/- 20ppm difference at 1500 m/z ; assign putative_ID

# %%
#create new column for abs of deltamz
pairs['abs_DeltaMZ'] = pairs['DeltaMZ'].abs()

# %%
#add putative ID of mass difference into column 'putative_ID'
pairs.loc[(pairs['abs_DeltaMZ'] > 13.956) & (pairs['abs_DeltaMZ'] < 14.076), 'putative_ID'] = 'CH2'
pairs.loc[(pairs['abs_DeltaMZ'] > 15.936) & (pairs['abs_DeltaMZ'] < 16.056), 'putative_ID'] = 'O'
pairs.loc[(pairs['abs_DeltaMZ'] > 27.972) & (pairs['abs_DeltaMZ'] < 28.092), 'putative_ID'] = 'C2H4'
#add in additional - if name not known, then make equal to the mean mass

# %%
#drop rows that don't have an entry in putative_ID
pairs['putative_ID'].replace('', np.nan, inplace=True)
pairs_subset = pairs.dropna(subset=['putative_ID'])

# %%
pairs_subset.head()
# Out:
#     CLUSTERID1  CLUSTERID2  DeltaMZ  MEH    Cosine  OtherScore  abs_DeltaMZ  \
# 6           91         123 -28.0290  0.0  0.905455    0.704403      28.0290
# 10         111         149 -28.0277  0.0  0.912133    0.938232      28.0277
# 19         147         172 -14.0200  0.0  0.818500    0.678544      14.0200
# 21         149         176 -15.9978  0.0  0.818981    0.667743      15.9978
# 22         149         199 -28.0378  0.0  0.821735    0.831735      28.0378
#
#    putative_ID
# 6         C2H4
# 10        C2H4
# 19         CH2
# 21           O
# 22        C2H4

# %%
#subset pairs df to omit low value cosine scores
pairs_subset = pairs_subset.loc[(pairs_subset['Cosine'] >= 0.8)]

# %% [markdown]
# # ID clustered spectra to add to library

# %% [markdown]
# Find the pairs, based on filtered input files. Create a column that contains the opposite clusterid, which is the scan number needed to add a new suspect annotation.

# %%
clusterid1_pairs = pd.merge(pairs_subset, IDs_subset, left_on='CLUSTERID1', right_on='#Scan#')
clusterid1_pairs['suspect_index'] = clusterid1_pairs['CLUSTERID2']
clusterid1_pairs['sign'] = '+'

# %%
clusterid2_pairs = pd.merge(pairs_subset, IDs_subset, left_on='CLUSTERID2', right_on='#Scan#')
clusterid2_pairs['suspect_index'] = clusterid2_pairs['CLUSTERID1']
clusterid2_pairs['sign'] = '-'

# %%
#concatenate the two dataframes
suspect_pairs = pd.concat([clusterid1_pairs, clusterid2_pairs])
suspect_pairs.reset_index(drop=True, inplace=True)

# %%
#define suspect compound name
suspect_pairs["Suspect Name"] = "Suspect related to " + suspect_pairs["Compound_Name"] + " " + suspect_pairs["sign"] + suspect_pairs["putative_ID"]

# %%
suspect_pairs
# Out:
#    CLUSTERID1  CLUSTERID2  DeltaMZ  MEH    Cosine  OtherScore  abs_DeltaMZ  \
# 0         147         172  -14.020  0.0  0.818500    0.678544       14.020
# 1        1520        1551  -15.998  0.0  0.835552    0.631343       15.998
# 2         386         410  -15.990  0.0  0.831178    0.598800       15.990
#
#   putative_ID    Compound_Name Ion_Source  ... MZErrorPPM SharedPeaks  \
# 0         CH2  C17-Sphinganine     LC-ESI  ...    3.38742           7
# 1           O      Beauvericin        ESI  ...    1.66515           7
# 2           O      Tyr-Pro-Phe        ESI  ...   18.04410           6
#
#    MassDiff    LibMZ  SpecMZ  SpecCharge  INCHI_TF  suspect_index  sign  \
# 0  0.000977  288.291  288.29           0      True            172     +
# 1  0.001343  806.399  806.40           0      True           1551     +
# 2  0.007690  426.202  426.21           0      True            386     -
#
#                               Suspect Name
# 0  Suspect related to C17-Sphinganine +CH2
# 1        Suspect related to Beauvericin +O
# 2        Suspect related to Tyr-Pro-Phe -O
#
# [3 rows x 47 columns]

# %%
suspect_pairs.columns
# Out:
# Index(['CLUSTERID1', 'CLUSTERID2', 'DeltaMZ', 'MEH', 'Cosine', 'OtherScore',
#        'abs_DeltaMZ', 'putative_ID', 'Compound_Name', 'Ion_Source',
#        'Instrument', 'Compound_Source', 'PI', 'Data_Collector', 'Adduct',
#        'Scan', 'Precursor_MZ', 'ExactMass', 'Charge', 'CAS_Number',
#        'Pubmed_ID', 'Smiles', 'INCHI', 'INCHI_AUX', 'Library_Class',
#        'SpectrumID', 'IonMode', 'UpdateWorkflowName', 'LibraryQualityString',
#        'TaskID', '#Scan#', 'SpectrumFile', 'LibraryName', 'MQScore',
#        'Organism', 'TIC_Query', 'RT_Query', 'MZErrorPPM', 'SharedPeaks',
#        'MassDiff', 'LibMZ', 'SpecMZ', 'SpecCharge', 'INCHI_TF',
#        'suspect_index', 'sign', 'Suspect Name'],
#       dtype='object')

# %%
#if this is a function, should spit out a warning
boolean = not suspect_pairs['Suspect Name'].is_unique
boolean

if boolean == True:
    print('There is more than one suspect match per LibraryID')

# %%
#if this is a function, should spit out a warning
boolean = not suspect_pairs['suspect_index'].is_unique
boolean

if boolean == True:
    print('There is more than one analog match per suspect scan')

# %%
#add in conditionals of what to change / or data to summarize with regards to overlaps

# %% [markdown]
# # Create output for suspect library

# %% [markdown]
# output: spectral library batch file
#
# #batch upload for adding spectral library
# (1 spectrum per analog)

# %%
suspect_pairs.columns
# Out:
# Index(['CLUSTERID1', 'CLUSTERID2', 'DeltaMZ', 'MEH', 'Cosine', 'OtherScore',
#        'abs_DeltaMZ', 'putative_ID', 'Compound_Name', 'Ion_Source',
#        'Instrument', 'Compound_Source', 'PI', 'Data_Collector', 'Adduct',
#        'Scan', 'Precursor_MZ', 'ExactMass', 'Charge', 'CAS_Number',
#        'Pubmed_ID', 'Smiles', 'INCHI', 'INCHI_AUX', 'Library_Class',
#        'SpectrumID', 'IonMode', 'UpdateWorkflowName', 'LibraryQualityString',
#        'TaskID', '#Scan#', 'SpectrumFile', 'LibraryName', 'MQScore',
#        'Organism', 'TIC_Query', 'RT_Query', 'MZErrorPPM', 'SharedPeaks',
#        'MassDiff', 'LibMZ', 'SpecMZ', 'SpecCharge', 'INCHI_TF',
#        'suspect_index', 'sign', 'Suspect Name'],
#       dtype='object')

# %%
new_suspect_pairs = suspect_pairs[['#Scan#', 'abs_DeltaMZ', 'Compound_Name', 'Precursor_MZ', 'Adduct', 'LibraryQualityString', 'SpectrumID', 'Suspect Name', 'suspect_index']].copy()

#columns to get from elsewhere: 'PI', 'Data Collector', 'Instrument', 'Ion_Source', 'IonMode' - based on the Unique Filepath

# %%
#the first columns refer to the annotation that was used to propagate to the suspect
#then come the suspect name, index
new_suspect_pairs
# Out:
#    #Scan#  abs_DeltaMZ    Compound_Name  Precursor_MZ Adduct  \
# 0     147       14.020  C17-Sphinganine       288.291    M+H
# 1    1520       15.998      Beauvericin       806.399   M+Na
# 2     410       15.990      Tyr-Pro-Phe       426.202    M+H
#
#   LibraryQualityString          SpectrumID  \
# 0               Bronze  CCMSLIB00000579284
# 1               Bronze  CCMSLIB00003416348
# 2               Bronze  CCMSLIB00003729791
#
#                               Suspect Name  suspect_index
# 0  Suspect related to C17-Sphinganine +CH2            172
# 1        Suspect related to Beauvericin +O           1551
# 2        Suspect related to Tyr-Pro-Phe -O            386

# %%
suspect_library = pd.merge(new_suspect_pairs, summary, left_on='suspect_index', right_on='cluster index')

# %%
suspect_library.head()
# Out:
#    #Scan#  abs_DeltaMZ    Compound_Name  Precursor_MZ Adduct  \
# 0     147        14.02  C17-Sphinganine       288.291    M+H
# 1     147        14.02  C17-Sphinganine       288.291    M+H
# 2     147        14.02  C17-Sphinganine       288.291    M+H
# 3     147        14.02  C17-Sphinganine       288.291    M+H
# 4     147        14.02  C17-Sphinganine       288.291    M+H
#
#   LibraryQualityString          SpectrumID  \
# 0               Bronze  CCMSLIB00000579284
# 1               Bronze  CCMSLIB00000579284
# 2               Bronze  CCMSLIB00000579284
# 3               Bronze  CCMSLIB00000579284
# 4               Bronze  CCMSLIB00000579284
#
#                               Suspect Name  suspect_index  cluster index  \
# 0  Suspect related to C17-Sphinganine +CH2            172            172
# 1  Suspect related to C17-Sphinganine +CH2            172            172
# 2  Suspect related to C17-Sphinganine +CH2            172            172
# 3  Suspect related to C17-Sphinganine +CH2            172            172
# 4  Suspect related to C17-Sphinganine +CH2            172            172
#
#                         AllFiles  sum(precursor intensity)    RTMean  \
# 0  inputspectra/spec-00012.mzXML                   85082.3  216.7520
# 1  inputspectra/spec-00012.mzXML                   88048.4  227.9790
# 2  inputspectra/spec-00016.mzXML                  119687.0   85.3721
# 3  inputspectra/spec-00016.mzXML                  105935.0   92.1508
# 4  inputspectra/spec-00016.mzXML                   33657.3  313.9400
#
#    RTStdErr  parent mass  ScanNumber     ProteosafeFilePath  \
# 0         0      302.310         102  spec/spec-00012.mzXML
# 1         0      302.310         109  spec/spec-00012.mzXML
# 2         0      302.310          55  spec/spec-00016.mzXML
# 3         0      302.309          60  spec/spec-00016.mzXML
# 4         0      303.310         184  spec/spec-00016.mzXML
#
#                                        Original_Path
# 0  f.MSV000078547/spectrum/DLab/121207_aby_B_DD_M...
# 1  f.MSV000078547/spectrum/DLab/121207_aby_B_DD_M...
# 2  f.MSV000078547/spectrum/DLab/121207_aby_D_DD_M...
# 3  f.MSV000078547/spectrum/DLab/121207_aby_D_DD_M...
# 4  f.MSV000078547/spectrum/DLab/121207_aby_D_DD_M...

# %%
suspect_library.to_csv('suspect_library_20200421.txt', sep='\t',index=False)

# %% [markdown]
# To investigate:
#
# Check if molecular formula varies by the same atoms as proposed based on the nominal mass difference?
