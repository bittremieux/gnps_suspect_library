# %%
import pandas as pd
import requests
import requests_cache
from tqdm import tqdm
import os
import glob
from markdown import markdown

requests_cache.install_cache('demo_cache', allowable_codes=(200,400,404,500))

# %%
# Reading frequent data
#suspect_list_df = pd.read_csv("suspect_library_freq.csv")
suspect_list_df = pd.read_csv("suspect_library_infreq.csv")

# %%
suspect_list_df.head()
# Out:
#                                                INCHI  \
# 0  InChI=1S/C29H50O2/c1-20(2)12-9-13-21(3)14-10-1...
# 1  InChI=1S/C27H36O10/c1-4-5-6-7-13-10-17(28)19-1...
# 2  InChI=1S/C15H20O4/c1-10(7-13(17)18)5-6-15(19)1...
# 3  InChI=1S/C15H20O4/c1-10(7-13(17)18)5-6-15(19)1...
# 4  InChI=1S/C15H20O4/c1-10(7-13(17)18)5-6-15(19)1...
#
#                                         CompoundName Adduct  DeltaMZ  \
# 0                             (+)-.alpha.-Tocopherol    M+H -193.059
# 1  (+)-11-Nor-.DELTA.9-tetrahydrocannabinol-9-car...    M+H  200.156
# 2                                  (+)-Abscisic acid   2M+H  184.093
# 3                                  (+)-Abscisic acid   2M+H  246.990
# 4                                  (+)-Abscisic acid   2M+H  247.110
#
#    GroupDeltaMZ AtomicDifference  \
# 0       -193.13              NaN
# 1        200.13  unknown|unknown
# 2        184.11          unknown
# 3        246.99              NaN
# 4        247.11              NaN
#
#                                            Rationale    Cosine  \
# 0                                                NaN  0.873882
# 1  2-amino-8-oxo-decanoic acid|N-methyl-4-butenyl...  0.817689
# 2                 2-carboxy-6-hydroxyoctahydroindole  0.801917
# 3                                                NaN  0.892768
# 4                                                NaN  0.906836
#
#    LibraryPrecursorMZ           LibraryID  ClusterScanNr  SuspectPrecursorMZ  \
# 0             431.388  CCMSLIB00003201507         244167             624.447
# 1             521.238  CCMSLIB00003493335         603029             321.082
# 2             529.280  CCMSLIB00003704198         164267             345.187
# 3             529.280  CCMSLIB00003226713          92338             282.290
# 4             529.280  CCMSLIB00003226714          56136             282.170
#
#    SuspectScanNr                                        SuspectPath
# 0           2802  f.MSV000083475/ccms_peak/RAW/PLATE7/7F5_8_55_s...
# 1            167  f.MSV000082493/ccms_peak/urine/DM000088438_RC1...
# 2           1473  f.MSV000079098/spectrum/GNPS_Cichewicz_Fungi_C...
# 3           3264  f.MSV000079356/ccms_peak/Plant/Plate2_BC4_01_8...
# 4            536  f.MSV000081810/ccms_peak/Exudates library/2015...

# %%
suspect_list_records = suspect_list_df.to_dict(orient="records")

# %%
for record in tqdm(suspect_list_records):
    inchi = record["INCHI"]
    if len(inchi) < 10:
        continue
    url = "https://gnps-structure.ucsd.edu/classyfire?inchi={}".format(inchi)
    r = requests.get(url)
    if r.status_code == 200:
        try:
            classyfire_json = r.json()
            record["superclass"] = classyfire_json["superclass"]["name"]
            record["class"] = classyfire_json["class"]["name"]
        except:
            continue
# Out:
# 100%|██████████| 7929/7929 [00:23<00:00, 331.01it/s]

# %%
# Getting Dataset Information
datasets_df = pd.DataFrame(requests.get("https://massive.ucsd.edu/ProteoSAFe/datasets_json.jsp").json()["datasets"])
datasets_df["DatasetInstrument"] = datasets_df["instrument"]
datasets_df = datasets_df[["dataset", "DatasetInstrument"]]

# %%
# Getting Library Information
libraries_df = pd.DataFrame(requests.get("https://gnps-external.ucsd.edu/gnpslibraryjson").json())
libraries_df["LibraryInstrument"] = libraries_df["Instrument"]
libraries_df = libraries_df[["spectrum_id", "LibraryInstrument"]]

# %%
suspect_list_df = pd.DataFrame(suspect_list_records)

suspect_list_df.to_csv("suspect_enriched.csv", sep=",", index=False)

def process_enrich(suspect_list_df):
    suspects = suspect_list_df
    
    suspects['dataset'] = suspects['SuspectPath'].str.slice(2, 14)
    suspects['usi1'] = ('mzspec:' + suspects['dataset'] + ':' +
                        suspects['SuspectPath'].apply(os.path.basename) +
                        ':scan:' + suspects['SuspectScanNr'].astype(str))
    suspects['usi2'] = 'mzspec:GNPSLIBRARY:' + suspects['LibraryID']
    # TODO: New style USI.
    # suspects['usi2'] = ('mzdraft:GNPS:GNPS-LIBRARY:accession:' +
    #                     suspects['LibraryID'])
    suspects['usi3'] = ('mzspec:MSV000084314:' + suspects['dataset'] +
                        '.mgf:scan:' + suspects['ClusterScanNr'].astype(str))
    
    mirror_urls = ('https://metabolomics-usi.ucsd.edu/mirror?usi1=' +
                   suspects['usi1'] + '&usi2=' + suspects['usi2'] +
                   '&mz_min=50&mz_max=500')
    mirror_alt_urls = ('https://metabolomics-usi.ucsd.edu/mirror?usi1=' +
                       suspects['usi1'] + '&usi2=' + suspects['usi3'] +
                       '&mz_min=50&mz_max=500')
    spectrum_urls = ('https://metabolomics-usi.ucsd.edu/spectrum/?usi=' +
                     suspects['usi1'] + '&mz_min=50&mz_max=500')
    
    suspects['mirror_urls'] = mirror_urls
    suspects['mirror_alt_urls'] = mirror_alt_urls
    suspects['spectrum_urls'] = spectrum_urls
    
    suspects = suspects.merge(datasets_df, how='left', on="dataset")
    suspects = suspects.merge(libraries_df, how='left', left_on="LibraryID", right_on="spectrum_id")
    
    return suspects
    
# Doing a filtration on the scan number to make sure its not -1
suspect_list_df = suspect_list_df[suspect_list_df["SuspectScanNr"] != -1]
suspect_list_df = process_enrich(suspect_list_df)

suspect_list_df = suspect_list_df[['CompoundName', 'Adduct', 'LibraryPrecursorMZ', 'DeltaMZ', "GroupDeltaMZ", "AtomicDifference", "Rationale", "superclass", "class", "LibraryInstrument", "DatasetInstrument", "mirror_urls", "mirror_alt_urls", "spectrum_urls", "INCHI", "SuspectPath"]]
suspect_list_df.to_csv("suspect_enriched_sheets.csv", sep=",", index=False)

# %%
all_classes = list(set(suspect_list_df["class"]))

# %%
output_folder = "class_split_suspects"
for class_name in all_classes:
    output_filename = os.path.join(output_folder, str(class_name) + ".csv")
    filtered_df = suspect_list_df[suspect_list_df["class"] == class_name]
    filtered_df.to_csv(output_filename, sep=",", index=False)

# %%
### Outputting mark down files

def process_md(input_filename, output_md, output_html):
    #suspects = pd.read_csv(input_filename).iloc
    suspects = pd.read_csv(input_filename)
    suspects['dataset'] = suspects['SuspectPath'].str.slice(2, 14)
    suspects['usi1'] = ('mzspec:' + suspects['dataset'] + ':' +
                        suspects['SuspectPath'].apply(os.path.basename) +
                        ':scan:' + suspects['SuspectScanNr'].astype(str))
    suspects['usi2'] = 'mzspec:GNPSLIBRARY:' + suspects['LibraryID']
    # TODO: New style USI.
    # suspects['usi2'] = ('mzdraft:GNPS:GNPS-LIBRARY:accession:' +
    #                     suspects['LibraryID'])
    suspects['usi3'] = ('mzspec:MSV000084314:' + suspects['dataset'] +
                        '.mgf:scan:' + suspects['ClusterScanNr'].astype(str))
    
    explanations = [
        ' / '.join([f'{atomic_diffs} ({rationales})'
                    for atomic_diffs, rationales in zip(atomic_diffs.split('|'),
                                                        rationales.split('|'))])
        for atomic_diffs, rationales in zip(
            suspects['AtomicDifference'].fillna('unknown'),
            suspects['Rationale'].fillna('unknown'))]

    output_list = ['| Suspect | Mirror Library | Mirror Dataset Cluster | Image |',
                   '| --- | --- | --- | --- |']
    suspects_str = ('<ul><li><b>Suspect:</b> ' + suspects['CompoundName'] + ' ['
                    + suspects['Adduct'] + '] '
                    + suspects['DeltaMZ'].map('{:=+9.3f}'.format) + ' ['
                    + suspects['GroupDeltaMZ'].map('{:+.2f}'.format) + ']'
                    + '</li>' +
                    '<li><b>Library:</b> [' + suspects['LibraryID'] + ']'
                    '(https://gnps.ucsd.edu/ProteoSAFe/gnpslibraryspectrum.jsp?'
                    'SpectrumID=' + suspects['LibraryID'] + ')'
                    + '</li>'
                    + '<li><b>Putative explanation:</b> ' + explanations
                    + '</li></ul>')
    mirror_urls = ('https://metabolomics-usi.ucsd.edu/svg/mirror?usi1=' +
                   suspects['usi1'] + '&usi2=' + suspects['usi2'] +
                   '&mz_min=50&mz_max=500')
    mirror_alt_urls = ('https://metabolomics-usi.ucsd.edu/svg/mirror?usi1=' +
                       suspects['usi1'] + '&usi2=' + suspects['usi3'] +
                       '&mz_min=50&mz_max=500')
    spectrum_urls = ('https://metabolomics-usi.ucsd.edu/svg/?usi=' +
                     suspects['usi1'] + '&mz_min=50&mz_max=500')
    for sus, url1, url2, url3 in zip(
            suspects_str, mirror_urls, mirror_alt_urls, spectrum_urls):
        output_list.append(f'| {sus} | ![]({url1}) | ![]({url2}) | [View USI]({url3})| ')
        
    with open(output_md, 'w') as f_out:
        f_out.write('\n'.join(output_list))
    with open(output_html, 'w') as f_out:
        f_out.write(markdown('\n'.join(output_list), extensions=['tables']))

# %%
input_csv_files = glob.glob(os.path.join(output_folder, "*.csv"))
output_md_folder = "class_split_suspects_md"
output_html_folder = "class_split_suspects_html"
for input_filename in input_csv_files:
    print(input_filename)
    output_md_filename = os.path.join(output_md_folder, os.path.basename(input_filename.replace('.csv', '.md')))
    output_html_filename = os.path.join(output_html_folder, os.path.basename(input_filename.replace('.csv', '.html')))
    
    process_md(input_filename, output_md_filename, output_html_filename)
# Out:
# class_split_suspects/Emetine alkaloids.csv
# class_split_suspects/Pteridines and derivatives.csv
# class_split_suspects/Kavalactones.csv
# class_split_suspects/Aporphines.csv
# class_split_suspects/5'-deoxyribonucleosides.csv
# class_split_suspects/Benzoxazines.csv
# class_split_suspects/Macrolides and analogues.csv
# class_split_suspects/Benzene and substituted derivatives.csv
# class_split_suspects/nan.csv
# class_split_suspects/Triphenyl compounds.csv
# class_split_suspects/Fatty Acyls.csv
# class_split_suspects/Thiadiazinanes.csv
# class_split_suspects/Pyrimidine nucleosides.csv
# class_split_suspects/Protopine alkaloids.csv
# class_split_suspects/Prenol lipids.csv
# class_split_suspects/Glycerolipids.csv
# class_split_suspects/Indanes.csv
# class_split_suspects/Naphthofurans.csv
# class_split_suspects/Benzothiazepines.csv
# class_split_suspects/Biotin and derivatives.csv
# class_split_suspects/Peptidomimetics.csv
# class_split_suspects/Stilbenes.csv
# class_split_suspects/Dithiolanes.csv
# class_split_suspects/Rhoeadine alkaloids.csv
# class_split_suspects/Yohimbine alkaloids.csv
# class_split_suspects/Benzothiazines.csv
# class_split_suspects/Purine nucleosides.csv
# class_split_suspects/Naphthalenes.csv
# class_split_suspects/Azoles.csv
# class_split_suspects/Saccharolipids.csv
# class_split_suspects/Hydroxy acids and derivatives.csv
# class_split_suspects/Organometalloid compounds.csv
# class_split_suspects/Pyrroles.csv
# class_split_suspects/2-arylbenzofuran flavonoids.csv
# class_split_suspects/Phthalide isoquinolines.csv
# class_split_suspects/Macrolactams.csv
# class_split_suspects/Carboximidic acids and derivatives.csv
# class_split_suspects/Benzimidazoles.csv
# class_split_suspects/Phenols.csv
# class_split_suspects/Benzazepines.csv
# class_split_suspects/Lactones.csv
# class_split_suspects/Linear 1,3-diarylpropanoids.csv
# class_split_suspects/Benzoxepines.csv
# class_split_suspects/Phenol ethers.csv
# class_split_suspects/Benzodiazepines.csv
# class_split_suspects/Azaphilones.csv
# class_split_suspects/Organooxygen compounds.csv
# class_split_suspects/Polypeptides.csv
# class_split_suspects/Lignan lactones.csv
# class_split_suspects/Quinolines and derivatives.csv
# class_split_suspects/Benzofurans.csv
# class_split_suspects/Organic thiophosphoric acids and derivatives.csv
# class_split_suspects/Angucyclines.csv
# class_split_suspects/Anthracenes.csv
# class_split_suspects/Piperidines.csv
# class_split_suspects/Keto acids and derivatives.csv
# class_split_suspects/Endocannabinoids.csv
# class_split_suspects/Coumarans.csv
# class_split_suspects/Isoindoles and derivatives.csv
# class_split_suspects/Pyrans.csv
# class_split_suspects/Glycerophospholipids.csv
# class_split_suspects/Organonitrogen compounds.csv
# class_split_suspects/Flavonoids.csv
# class_split_suspects/Diarylheptanoids.csv
# class_split_suspects/Diazinanes.csv
# class_split_suspects/Isocoumarins and derivatives.csv
# class_split_suspects/Depsides and depsidones.csv
# class_split_suspects/Ergoline and derivatives.csv
# class_split_suspects/Tetrapyrroles and derivatives.csv
# class_split_suspects/Coumarins and derivatives.csv
# class_split_suspects/Furanoid lignans.csv
# class_split_suspects/Lignan glycosides.csv
# class_split_suspects/Oxazinanes.csv
# class_split_suspects/Cinnamaldehydes.csv
# class_split_suspects/Steroids and steroid derivatives.csv
# class_split_suspects/Cinchona alkaloids.csv
# class_split_suspects/Phenanthrenes and derivatives.csv
# class_split_suspects/Pyridines and derivatives.csv
# class_split_suspects/Neoflavonoids.csv
# class_split_suspects/Aryltetralin lignans.csv
# class_split_suspects/Dibenzylbutane lignans.csv
# class_split_suspects/Pyrimidine nucleotides.csv
# class_split_suspects/Organic dithiophosphoric acids and derivatives.csv
# class_split_suspects/Naphthopyrans.csv
# class_split_suspects/Purine nucleotides.csv
# class_split_suspects/Phenylpropanoic acids.csv
# class_split_suspects/Arylnaphthalene lignans.csv
# class_split_suspects/Tetralins.csv
# class_split_suspects/Indoles and derivatives.csv
# class_split_suspects/Benzopyrans.csv
# class_split_suspects/Protoberberine alkaloids and derivatives.csv
# class_split_suspects/Triazines.csv
# class_split_suspects/Furopyridines.csv
# class_split_suspects/Organic phosphoric acids and derivatives.csv
# class_split_suspects/Oxepanes.csv
# class_split_suspects/Isobenzofurans.csv
# class_split_suspects/Imidazopyrimidines.csv
# class_split_suspects/Tannins.csv
# class_split_suspects/Isoquinolines and derivatives.csv
# class_split_suspects/Diazanaphthalenes.csv
# class_split_suspects/Morphinans.csv
# class_split_suspects/Isoflavonoids.csv
# class_split_suspects/Dibenzocycloheptenes.csv
# class_split_suspects/Indenes and isoindenes.csv
# class_split_suspects/Organic sulfuric acids and derivatives.csv
# class_split_suspects/Carboxylic acids and derivatives.csv
# class_split_suspects/Diazines.csv
# class_split_suspects/Benzodioxoles.csv
# class_split_suspects/Aurone flavonoids.csv
