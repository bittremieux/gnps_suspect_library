# %%
import pandas as pd
import requests
import requests_cache
from tqdm import tqdm

# %%
# Reading frequent data
suspect_list_df = pd.read_csv("suspect_library_freq.csv")

# %%
suspect_list_df.head()
# Out:
#                                                INCHI            CompoundName  \
# 0  InChI=1S/C29H50O2/c1-20(2)12-9-13-21(3)14-10-1...  (+)-.alpha.-Tocopherol
# 1  InChI=1S/C29H50O2/c1-20(2)12-9-13-21(3)14-10-1...  (+)-.alpha.-Tocopherol
# 2  InChI=1S/C29H50O2/c1-20(2)12-9-13-21(3)14-10-1...  (+)-.alpha.-Tocopherol
# 3  InChI=1S/C29H50O2/c1-20(2)12-9-13-21(3)14-10-1...  (+)-.alpha.-Tocopherol
# 4  InChI=1S/C29H50O2/c1-20(2)12-9-13-21(3)14-10-1...  (+)-.alpha.-Tocopherol
#
#   Adduct  DeltaMZ  GroupDeltaMZ AtomicDifference                Rationale  \
# 0    M+H -160.194       -160.03              NaN                      NaN
# 1    M+H  -61.979        -61.95              NaN                      NaN
# 2    M+H  -42.011        -42.05   2C,4H,1N|3C,H6          unknown|unknown
# 3    M+H  -21.945        -21.99      none_adduct  proton to sodium adduct
# 4    M+H  -11.965        -11.99               1C                  unknown
#
#      Cosine  LibraryPrecursorMZ           LibraryID  ClusterScanNr  \
# 0  0.870260             431.388  CCMSLIB00003201505           2380
# 1  0.912820             431.388  CCMSLIB00003201505           3979
# 2  0.802901             431.388  CCMSLIB00003201507         142984
# 3  0.805319             431.388  CCMSLIB00003201507           2550
# 4  0.855681             431.388  CCMSLIB00003201507         244167
#
#    SuspectPrecursorMZ  SuspectScanNr  \
# 0             591.582           1201
# 1             493.367            286
# 2             473.399           3322
# 3             453.333           1297
# 4             443.353           2531
#
#                                          SuspectPath
# 0  f.MSV000082719/ccms_peak/ST000685/EX00694-lipi...
# 1  f.MSV000082705/ccms_peak/ST000681/EX00680-lipi...
# 2  f.MSV000083300/ccms_peak/Data_raw/Positive/Sam...
# 3  f.MSV000082726/ccms_peak/ST000686/EX00713-lipi...
# 4  f.MSV000083475/ccms_peak/RAW/PLATE6/6B8_5_8_mo...

# %%
suspect_list_records = suspect_list_df.to_dict(orient="records")

# %%
for record in tqdm(suspect_list_records):
    inchi = record["INCHI"]
    url = "https://gnps-structure.ucsd.edu/classyfire?inchi={}".format(inchi)
    r = requests.get(url)
    if r.status_code == 200:
        try:
            classyfire_json = r.json()
            record["superclass"] = classyfire_json["superclass"]["name"]
            record["class"] = classyfire_json["class"]["name"]
        except:
            continue
# Out:
#   2%|▏         | 575/31700 [01:30<1:21:14,  6.38it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-61ce0b4c17a0> in <module>
#       2     inchi = record["INCHI"]
#       3     url = "https://gnps-structure.ucsd.edu/classyfire?inchi={}".format(inchi)
# ----> 4     r = requests.get(url)
#       5     if r.status_code == 200:
#       6         try:
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     298     def connect(self):
#     299         # Add certificate verification
# --> 300         conn = self._new_conn()
#     301         hostname = self.host
#     302
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     155         try:
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#     159
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59     family = allowed_gai_family()
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#      63         sock = None
#
# ~/miniconda3/envs/jupyterlab/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     750     # and socket type values to enum constants.
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     753         af, socktype, proto, canonname, sa = res
#     754         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:
